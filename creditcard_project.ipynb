# %%
import pandas as pd

# %%
df_cust = pd.read_csv("C:\\Users\\sravi\\Downloads\\chapter8_assets\\datasets\\customers.csv")
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0       358211.0        Married
# 1        65172.0         Single
# 2        22378.0        Married
# 3        33563.0        Married
# 4        39406.0        Married

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000     950.000000
# mean    500.500000    36.405000  139410.314737
# std     288.819436    15.666155  112416.802007
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   47627.500000
# 50%     500.500000    32.000000  112218.500000
# 75%     750.250000    46.000000  193137.500000
# max    1000.000000   135.000000  449346.000000

# %%
df_cs = pd.read_csv("C:\\Users\\sravi\\Downloads\\chapter8_assets\\datasets\\credit_profiles.csv")
df_trans = pd.read_csv("C:\\Users\\sravi\\Downloads\\chapter8_assets\\datasets\\transactions.csv")

# %%
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_cust.isnull().sum()
# Out:
# cust_id            0
# name               0
# gender             0
# age                0
# location           0
# occupation         0
# annual_income     50
# marital_status     0
# dtype: int64

# %%
df_cust.annual_income.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999    False
# Name: annual_income, Length: 1000, dtype: bool

# %%
df_cust[df_cust.annual_income.isna()]
# Out:
#      cust_id               name  gender  age location           occupation  \
# 14        15      Sanjana Malik  Female   25    Rural               Artist
# 82        83  Reyansh Mukherjee    Male   27     City           Freelancer
# 97        98         Virat Puri    Male   47   Suburb       Business Owner
# 102      103         Aarav Shah    Male   32     City       Data Scientist
# 155      156       Kiaan Saxena    Male   24     City  Fullstack Developer
# 170      171       Advait Verma    Male   52     City       Business Owner
# 186      187       Samar Sardar    Male   53     City           Consultant
# 192      193        Ishan Joshi    Male   37   Suburb       Data Scientist
# 227      228   Advait Mukherjee    Male   48     City       Business Owner
# 232      233        Aditya Goel    Male   26     City           Freelancer
# 240      241        Aaryan Bose    Male   24   Suburb           Freelancer
# ...

# %%
df_cust.annual_income.median()
# Out:
# 112218.5

# %%
df_cust[df_cust.occupation == "Artist"].annual_income.median()
# Out:
# 45794.0

# %%
occupation_wise_inc_median = df_cust.groupby("occupation")["annual_income"].median()
occupation_wise_inc_median
# Out:
# occupation
# Accountant              65265.0
# Artist                  45794.0
# Business Owner         261191.5
# Consultant              58017.0
# Data Scientist         135759.0
# Freelancer              46759.0
# Fullstack Developer     76774.0
# Name: annual_income, dtype: float64

# %%
def median_value(row):
    if pd.isnull(row["annual_income"]):
         return occupation_wise_inc_median[row["occupation"]]
    else:
        return row["annual_income"]

# %%
df_cust["annual_income"] = df_cust.apply(lambda row :occupation_wise_inc_median[row["occupation"]] if pd.isnull(row["annual_income"])
                            else row["annual_income"],axis = 1)

# %%
df_cust.isnull().sum()
# Out:
# cust_id           0
# name              0
# gender            0
# age               0
# location          0
# occupation        0
# annual_income     0
# marital_status    0
# dtype: int64

# %%
df_cust.iloc[[14,82]]
# Out:
#     cust_id               name  gender  age location  occupation  \
# 14       15      Sanjana Malik  Female   25    Rural      Artist
# 82       83  Reyansh Mukherjee    Male   27     City  Freelancer
#
#     annual_income marital_status
# 14        45794.0        Married
# 82        46759.0         Single

# %%
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from matplotlib import pyplot as plt

# %%
plt.figure(figsize = (5,5))
sns.histplot(df_cust['annual_income'],kde = True ,color = 'green',label = "Data")
plt.title('Histogram of annual_income')
plt.show()

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  138916.765500
# std     288.819436    15.666155  110969.408643
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   48229.500000
# 50%     500.500000    32.000000  113416.000000
# 75%     750.250000    46.000000  192614.000000
# max    1000.000000   135.000000  449346.000000

# %%
df_cust[df_cust.annual_income<100]
# Out:
#      cust_id            name  gender  age location           occupation  \
# 31        32     Veer Mistry    Male   50     City       Business Owner
# 262      263   Vivaan Tandon    Male   53   Suburb       Business Owner
# 316      317   Yuvraj Saxena    Male   47     City           Consultant
# 333      334    Avani Khanna  Female   29     City       Data Scientist
# 340      341     Priya Sinha  Female   33    Rural  Fullstack Developer
# 543      544    Advait Batra    Male   54     City           Consultant
# 592      593    Priya Gandhi  Female   32     City       Business Owner
# 633      634   Rudra Mehtani    Male   26     City       Data Scientist
# 686      687  Vihaan Jaiswal    Male   40     City       Business Owner
# 696      697      Ishan Negi    Male   47     City           Consultant
#
#      annual_income marital_status
# 31            50.0        Married
# 262           50.0        Married
# 316           50.0        Married
# 333           50.0        Married
# ...

# %%
occupation_wise_inc_median
# Out:
# occupation
# Accountant              65265.0
# Artist                  45794.0
# Business Owner         261191.5
# Consultant              58017.0
# Data Scientist         135759.0
# Freelancer              46759.0
# Fullstack Developer     76774.0
# Name: annual_income, dtype: float64

# %%
for index, row in df_cust.iterrows():
    if row["annual_income"]<100:
        print(row)
# Out:
# cust_id                       32
# name                 Veer Mistry
# gender                      Male
# age                           50
# location                    City
# occupation        Business Owner
# annual_income               50.0
# marital_status           Married
# Name: 31, dtype: object
# cust_id                      263
# name               Vivaan Tandon
# gender                      Male
# age                           53
# location                  Suburb
# occupation        Business Owner
# annual_income               50.0
# marital_status           Married
# Name: 262, dtype: object
# cust_id                     317
# name              Yuvraj Saxena
# gender                     Male
# age                          47
# location                   City
# occupation           Consultant
# annual_income              50.0
# marital_status          Married
# Name: 316, dtype: object
# cust_id                      334
# name                Avani Khanna
# ...

# %%
for index, row in df_cust.iterrows():
    if row["annual_income"]<100:
        df_cust.at[index,"annual_income"] = occupation_wise_inc_median[row["occupation"]]

# %%
df_cust.loc[[31,316]]
# Out:
#      cust_id           name gender  age location      occupation  \
# 31        32    Veer Mistry   Male   50     City  Business Owner
# 316      317  Yuvraj Saxena   Male   47     City      Consultant
#
#      annual_income marital_status
# 31        261191.5        Married
# 316        58017.0        Married

# %%
avg_income_per_occuaption = df_cust.groupby("occupation")["annual_income"].mean()
avg_income_per_occuaption
# Out:
# occupation
# Accountant              64123.562500
# Artist                  45309.236842
# Business Owner         268447.368512
# Consultant              60703.154639
# Data Scientist         137021.266304
# Freelancer              76327.508772
# Fullstack Developer     78727.972973
# Name: annual_income, dtype: float64

# %%
avg_income_per_occuaption.index
# Out:
# Index(['Accountant', 'Artist', 'Business Owner', 'Consultant',
#        'Data Scientist', 'Freelancer', 'Fullstack Developer'],
#       dtype='object', name='occupation')

# %%
avg_income_per_occuaption.values
# Out:
# array([ 64123.5625    ,  45309.23684211, 268447.36851211,  60703.15463918,
#        137021.26630435,  76327.50877193,  78727.97297297])

# %%
sns.barplot(x = avg_income_per_occuaption.index, y =avg_income_per_occuaption .values, palette = "tab10")
plt.xticks(rotation= 45)
plt.title("Average Annual Income per occupation")
plt.xlabel("Occupation")
plt.ylabel("Average Annual Income($)")
plt.show()

# %%
catgeorical_columns = ['gender','location','occupation', 'marital_status']

for col in catgeorical_columns: 
   
    plt.figure(figsize = (8,4))
    avg_income_per_group = df_cust.groupby(col)['annual_income'].mean().sort_values()
    sns.barplot(x = avg_income_per_group.index, y = avg_income_per_group.values, palette = "tab10")
    plt.xticks(rotation = 45)
  
    plt.xlabel(col.capitalize())
    plt.ylabel('Average Annual Income($)')
    plt.show()

# %%
df_cust.isnull().sum()
# Out:
# cust_id           0
# name              0
# gender            0
# age               0
# location          0
# occupation        0
# annual_income     0
# marital_status    0
# dtype: int64

# %%
df_cust.age.describe()
# Out:
# count    1000.000000
# mean       36.405000
# std        15.666155
# min         1.000000
# 25%        26.000000
# 50%        32.000000
# 75%        46.000000
# max       135.000000
# Name: age, dtype: float64

# %%
plt.hist(df_cust.age, bins=20 , edgecolor = "black")

plt.show()

# %%
outliers = df_cust[(df_cust.age<15)|(df_cust.age >80)]
outliers
# Out:
#      cust_id             name  gender  age location           occupation  \
# 0          1    Manya Acharya  Female    2     City       Business Owner
# 41        42      Aaryan Shah    Male  110     City               Artist
# 165      166        Sia Dutta  Female    1     City           Freelancer
# 174      175     Rohan Sharma    Male  110     City           Freelancer
# 222      223      Arjun Batra    Male  110   Suburb           Freelancer
# 277      278     Aarav Tandon    Male  110     City           Consultant
# 295      296     Ayush Pandey    Male    1    Rural           Accountant
# 325      326       Virat Goel    Male  110     City           Accountant
# 610      611      Rehan Verma    Male  135    Rural       Business Owner
# 692      693        Dhruv Jha    Male    1     City       Business Owner
# 703      704     Aanya Sharma  Female  110     City           Freelancer
# 709      710      Anika Verma  Female  110     City       Data Scientist
# ...

# %%
df_cust.age.median()
# Out:
# 32.0

# %%
median_age_occupation = df_cust.groupby("occupation")["age"].median()
median_age_occupation
# Out:
# occupation
# Accountant             31.5
# Artist                 26.0
# Business Owner         51.0
# Consultant             46.0
# Data Scientist         32.0
# Freelancer             24.0
# Fullstack Developer    27.5
# Name: age, dtype: float64

# %%
for index, row in outliers.iterrows():
    df_cust.at[index,'age'] = median_age_occupation[row['occupation']]

# %%
df_cust[(df_cust.age<15)|(df_cust.age >80)]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    35.541500  140483.548500
# std     288.819436    12.276634  110463.002934
# min       1.000000    18.000000    5175.000000
# 25%     250.750000    26.000000   49620.500000
# 50%     500.500000    32.000000  115328.000000
# 75%     750.250000    44.250000  195514.250000
# max    1000.000000    64.000000  449346.000000

# %%
#Define the bin edges and labels
bin_edges = [17,25,48,65]
bin_labels = ['18-25','26-48','49-65']

#Use the cut function to bin and label the age column
df_cust['age_group'] = pd.cut(df_cust['age'], bins = bin_edges, labels = bin_labels)
df_cust.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
age_group_counts = df_cust.age_group.value_counts(normalize = True)*100
age_group_counts
# Out:
# age_group
# 26-48    56.7
# 18-25    24.6
# 49-65    18.7
# Name: proportion, dtype: float64

# %%
type(age_group_counts)
# Out:
# pandas.core.series.Series

# %%
age_group_counts.index
# Out:
# CategoricalIndex(['26-48', '18-25', '49-65'], categories=['18-25', '26-48', '49-65'], ordered=True, dtype='category', name='age_group')

# %%
plt.pie(
    age_group_counts, 
    labels = age_group_counts.index,
    autopct = '%1.2f%%', 
    shadow = True, 
    explode = (0.1,0,0), 
    startangle = 140
)

plt.show()

# %%
df_cust.location.value_counts()
# Out:
# location
# City      683
# Suburb    232
# Rural      85
# Name: count, dtype: int64

# %%
df_cust.gender.value_counts()
# Out:
# gender
# Male      674
# Female    326
# Name: count, dtype: int64

# %%
customer_location_gender = df_cust.groupby(['location','gender']).size().unstack()
customer_location_gender
# Out:
# gender    Female  Male
# location
# City         226   457
# Rural         26    59
# Suburb        74   158

# %%
import matplotlib.pyplot as plt

customer_location_gender.plot(kind='bar', stacked=True, figsize=(5,4))

plt.legend(title="Gender")
plt.xlabel('location')
plt.show()

# %%
df_cs.shape
# Out:
# (1004, 6)

# %%
df_cs['cust_id'].nunique()
# Out:
# 1000

# %%
df_cs[df_cs['cust_id'].duplicated(keep = False)]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 516      517           308                 NaN               NaN
# 517      517           308            0.113860              33.0
# 569      569           344                 NaN               NaN
# 570      569           344            0.112599              37.0
# 607      606           734                 NaN               NaN
# 608      606           734            0.193418            4392.0
# 664      662           442                 NaN               NaN
# 665      662           442            0.856039             266.0
#
#      credit_inquiries_last_6_months  credit_limit
# 516                             NaN           NaN
# 517                             3.0         500.0
# 569                             NaN           NaN
# 570                             0.0         500.0
# 607                             NaN           NaN
# 608                             1.0       40000.0
# ...

# %%
df_cs_clean_1 = df_cs.drop_duplicates(subset="cust_id", keep = "last")
df_cs_clean_1
# Out:
#       cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0           1           749            0.585171           19571.0
# 1           2           587            0.107928          161644.0
# 2           3           544            0.854807             513.0
# 3           4           504            0.336938             224.0
# 4           5           708            0.586151           18090.0
# ...       ...           ...                 ...               ...
# 999       996           564            0.702963             688.0
# 1000      997           774            0.465462           17139.0
# 1001      998           529            0.585856             386.0
# 1002      999           725            0.249670            6973.0
# 1003     1000           775            0.696050           33956.0
#
#       credit_inquiries_last_6_months  credit_limit
# 0                                0.0       40000.0
# 1                                2.0        1250.0
# ...

# %%
df_cs_clean_1[df_cs_clean_1['cust_id'].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit]
# Index: []

# %%
df_cs_clean_1.isnull().sum()
# Out:
# cust_id                            0
# credit_score                       0
# credit_utilisation                 0
# outstanding_debt                   0
# credit_inquiries_last_6_months     0
# credit_limit                      65
# dtype: int64

# %%
df_cs_clean_1[df_cs_clean_1.credit_limit.isnull()]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 10        11           679            0.557450            9187.0
# 35        36           790            0.112535            4261.0
# 37        38           514            0.296971             238.0
# 45        46           761            0.596041           24234.0
# 64        65           734            0.473715           13631.0
# ..       ...           ...                 ...               ...
# 912      909           479            0.487555             320.0
# 931      928           311            0.832244             316.0
# 948      945           526            0.272734             227.0
# 954      951           513            0.175914             131.0
# 957      954           783            0.867421           46451.0
#
#      credit_inquiries_last_6_months  credit_limit
# 10                              2.0           NaN
# 35                              1.0           NaN
# ...

# %%
df_cs_clean_1.credit_limit.value_counts()
# Out:
# credit_limit
# 500.0      229
# 60000.0    186
# 40000.0    137
# 1500.0     100
# 1000.0      90
# 750.0       76
# 1250.0      75
# 20000.0     42
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,5))
plt.scatter(df_cs_clean_1.credit_limit, df_cs_clean_1.credit_score, c = 'blue', marker = 'o', label= 'Data Points')

plt.title('Credit Score vs. Credit Limit')
plt.xlabel('Credit Limit')
plt.ylabel('Credit Score')

#Adjust the y-axis bin interval to 1000
plt.xticks(range(0,90001,5000))
plt.grid(True)

#Show the plot
plt.legend()

plt.show()

# %%
bin_ranges = [300,450,500,550,600,650,700,750,800]

bin_labels = [f'{start}-{end-1}' for start, end in zip(bin_ranges, bin_ranges[1:])]

df_cs_clean_1['credit_score_range'] = pd.cut(df_cs_clean_1['credit_score'],bins = bin_ranges, labels = bin_labels)

# %%
df_cs_clean_1.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749

# %%
df_cs_clean_1[df_cs_clean_1.credit_score_range == "700-749"]
# Out:
#       cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0           1           749            0.585171           19571.0
# 4           5           708            0.586151           18090.0
# 6           7           747            0.523965           15544.0
# 16         17           702            0.894423           18444.0
# 27         28           729            0.149748            3453.0
# ...       ...           ...                 ...               ...
# 969       966           720            0.203742            6159.0
# 970       967           739            0.845474           23929.0
# 991       988           739            0.435891            9283.0
# 994       991           709            0.718484           15473.0
# 1002      999           725            0.249670            6973.0
#
#       credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                                0.0       40000.0            700-749
# ...

# %%
mode_df = df_cs_clean_1.groupby("credit_score_range")["credit_limit"].agg(lambda x: x.mode().iloc[0]).reset_index()
mode_df
# Out:
#   credit_score_range  credit_limit
# 0            300-449         500.0
# 1            450-499         750.0
# 2            500-549        1000.0
# 3            550-599        1250.0
# 4            600-649        1500.0
# 5            650-699       20000.0
# 6            700-749       40000.0
# 7            750-799       60000.0

# %%
df_cs_clean_1[df_cs_clean_1.credit_limit.isnull()].sample(3)
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 650      648           405            0.231599              63.0
# 211      212           337            0.608700             226.0
# 469      470           795            0.776496           33523.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range
# 650                             0.0           NaN            300-449
# 211                             4.0           NaN            300-449
# 469                             4.0           NaN            750-799

# %%
df_cs_clean_2 = pd.merge(df_cs_clean_1, mode_df, on = "credit_score_range", suffixes = ("", "_mode"))
df_cs_clean_2
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0          1           749            0.585171           19571.0
# 1          5           708            0.586151           18090.0
# 2          7           747            0.523965           15544.0
# 3         17           702            0.894423           18444.0
# 4         28           729            0.149748            3453.0
# ..       ...           ...                 ...               ...
# 994      985           770            0.628088           33405.0
# 995      990           772            0.259958           11937.0
# 996      993           782            0.477170           20305.0
# 997      997           774            0.465462           17139.0
# 998     1000           775            0.696050           33956.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                               0.0       40000.0            700-749
# ...

# %%
df_cs_clean_2 [df_cs_clean_2 .credit_limit.isnull()].sample(3)
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 372      212           337            0.608700             226.0
# 890      478           757            0.160767            6286.0
# 981      899           775            0.487290           21548.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 372                             4.0           NaN            300-449
# 890                             2.0           NaN            750-799
# 981                             0.0           NaN            750-799
#
#      credit_limit_mode
# 372              500.0
# 890            60000.0
# 981            60000.0

# %%
df_cs_clean_3 = df_cs_clean_2.copy()
df_cs_clean_3['credit_limit'].fillna(df_cs_clean_3['credit_limit_mode'], inplace = True)
df_cs_clean_3.shape
# Out:
# (999, 8)

# %%
df_cs_clean_3.isnull().sum()
# Out:
# cust_id                           0
# credit_score                      0
# credit_utilisation                0
# outstanding_debt                  0
# credit_inquiries_last_6_months    0
# credit_limit                      0
# credit_score_range                0
# credit_limit_mode                 0
# dtype: int64

# %%
df_cs_clean_3.loc[[717,869]]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 717      356           626            0.287290             219.0
# 869      390           754            0.656635           24274.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 717                             1.0        1500.0            600-649
# 869                             3.0       60000.0            750-799
#
#      credit_limit_mode
# 717             1500.0
# 869            60000.0

# %%
df_cs_clean_3.describe()
# Out:
#            cust_id  credit_score  credit_utilisation  outstanding_debt  \
# count   999.000000    999.000000          999.000000        999.000000
# mean    500.323323    589.471471            0.498663       9692.948949
# std     288.910029    152.085696            0.233079      25266.811373
# min       1.000000    301.000000            0.103761         33.000000
# 25%     250.500000    460.000000            0.293785        221.000000
# 50%     500.000000    602.000000            0.487290        551.000000
# 75%     750.500000    738.000000            0.697670      11839.000000
# max    1000.000000    799.000000            0.899648     209901.000000
#
#        credit_inquiries_last_6_months  credit_limit  credit_limit_mode
# count                      999.000000    999.000000         999.000000
# mean                         1.955956  19752.752753       19752.752753
# std                          1.414944  24722.506641       24722.506641
# ...

# %%
import seaborn as sns
sns.boxplot(x =df_cs_clean_3.outstanding_debt )
# Out:
# <Axes: xlabel='outstanding_debt'>

# %%
df_cs_clean_3[df_cs_clean_3.outstanding_debt > df_cs_clean_3.credit_limit]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 6         39           734            0.573023          122758.0
# 13        94           737            0.739948          137058.0
# 38       272           703            0.446886          154568.0
# 44       302           722            0.608076          122402.0
# 105      726           737            0.136048          205404.0
# 148        2           587            0.107928          161644.0
# 369      205           303            0.364360          187849.0
# 412      351           320            0.285081          150860.0
# 482      637           420            0.323984          140063.0
# 613      647           498            0.658087          128818.0
# 618      724           465            0.658173          140008.0
# 623      767           473            0.611750          195004.0
# 689       20           647            0.439132          205014.0
# ...

# %%
df_cs_clean_3.loc[df_cs_clean_3.outstanding_debt > df_cs_clean_3.credit_limit,'outstanding_debt'] = df_cs_clean_3['credit_limit']

# %%
df_cs_clean_3[df_cs_clean_3.outstanding_debt > df_cs_clean_3.credit_limit]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit, credit_score_range, credit_limit_mode]
# Index: []

# %%
df_cs_clean_3.loc[[6,13]]
# Out:
#     cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 6        39           734            0.573023           40000.0
# 13       94           737            0.739948           40000.0
#
#     credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 6                              3.0       40000.0            700-749
# 13                             2.0       40000.0            700-749
#
#     credit_limit_mode
# 6             40000.0
# 13            40000.0

# %%
df_cs_clean_3.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        5           708            0.586151           18090.0
# 2        7           747            0.523965           15544.0
# 3       17           702            0.894423           18444.0
# 4       28           729            0.149748            3453.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                             0.0       40000.0            700-749
# 1                             2.0       40000.0            700-749
# 2                             4.0       40000.0            700-749
# 3                             0.0       40000.0            700-749
# 4                             2.0       40000.0            700-749
#
#    credit_limit_mode
# 0            40000.0
# 1            40000.0
# 2            40000.0
# 3            40000.0
# 4            40000.0

# %%
df_cust.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
df_merged = df_cust.merge(df_cs_clean_3, on = "cust_id", how = "inner")
df_merged
# Out:
#      cust_id              name  gender   age location           occupation  \
# 0          1     Manya Acharya  Female  51.0     City       Business Owner
# 1          2     Anjali Pandey  Female  47.0     City           Consultant
# 2          3    Aaryan Chauhan    Male  21.0     City           Freelancer
# 3          4        Rudra Bali    Male  24.0    Rural           Freelancer
# 4          5      Advait Malik    Male  48.0     City           Consultant
# ..       ...               ...     ...   ...      ...                  ...
# 994      996    Manya Vasudeva  Female  26.0     City           Freelancer
# 995      997      Aarav Dhawan    Male  55.0     City       Business Owner
# 996      998         Rehan Jha    Male  29.0     City  Fullstack Developer
# 997      999     Amara Rathore  Female  47.0     City       Business Owner
# 998     1000  Akshay Choudhary    Male  28.0     City           Freelancer
#
# ...

# %%
df_merged[["credit_score", "credit_limit"]].corr()
# Out:
#               credit_score  credit_limit
# credit_score      1.000000      0.848261
# credit_limit      0.848261      1.000000

# %%
numerical_cols = ['credit_score', 'credit_utilisation','outstanding_debt','credit_limit','annual_income']

correlation_matrix = df_merged[numerical_cols].corr()
correlation_matrix
# Out:
#                     credit_score  credit_utilisation  outstanding_debt  \
# credit_score            1.000000           -0.068281          0.680852
# credit_utilisation     -0.068281            1.000000          0.193771
# outstanding_debt        0.680852            0.193771          1.000000
# credit_limit            0.848261           -0.079631          0.810502
# annual_income           0.575794           -0.085740          0.555506
#
#                     credit_limit  annual_income
# credit_score            0.848261       0.575794
# credit_utilisation     -0.079631      -0.085740
# outstanding_debt        0.810502       0.555506
# credit_limit            1.000000       0.684653
# annual_income           0.684653       1.000000

# %%
sns.heatmap(correlation_matrix, annot = True,fmt ='.2f', cmap = 'RdYlBu', linewidths= 0.8)

plt.title('Correlation Plot')
plt.show()

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_trans.isnull().sum()
# Out:
# tran_id                0
# cust_id                0
# tran_date              0
# tran_amount            0
# platform            4941
# product_category       0
# payment_type           0
# dtype: int64

# %%
df_trans[df_trans.platform.isna()]
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform   product_category  \
# 355         356       58  2023-01-01          237      NaN        Electronics
# 418         419      383  2023-01-01          338      NaN        Electronics
# 607         608      421  2023-01-01          700      NaN        Electronics
# 844         845      945  2023-01-01          493      NaN             Sports
# 912         913      384  2023-01-01           85      NaN  Fashion & Apparel
# ...         ...      ...         ...          ...      ...                ...
# 499579   499580      924  2023-09-05           31      NaN  Fashion & Apparel
# 499646   499647      944  2023-09-05        58445      NaN  Fashion & Apparel
# 499725   499726      620  2023-09-05           15      NaN             Sports
# 499833   499834      616  2023-09-05           97      NaN  Fashion & Apparel
# 499997   499998       57  2023-09-05          224      NaN   Garden & Outdoor
#
#        payment_type
# ...

# %%
df_trans.platform.unique()
# Out:
# array(['Flipkart', 'Alibaba', 'Shopify', 'Amazon', 'Ebay', 'Meesho',
#        'Cred', nan], dtype=object)

# %%
df_trans.platform.mode()
# Out:
# 0    Amazon
# Name: platform, dtype: object

# %%
df_trans.platform.value_counts()
# Out:
# platform
# Amazon      151443
# Flipkart    122660
# Alibaba      73584
# Meesho       73271
# Shopify      39416
# Cred         24741
# Ebay          9944
# Name: count, dtype: int64

# %%
sns.countplot(y= 'product_category',hue ='platform' ,data = df_trans)
# Out:
# <Axes: xlabel='count', ylabel='product_category'>

# %%
df_trans.platform.mode()[0]
# Out:
# 'Amazon'

# %%
df_trans.platform.fillna(df_trans.platform.mode()[0], inplace = True)

# %%
df_trans.isnull().sum()
# Out:
# tran_id             0
# cust_id             0
# tran_date           0
# tran_amount         0
# platform            0
# product_category    0
# payment_type        0
# dtype: int64

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id   tran_amount
# count  500000.000000  500000.000000  500000.00000
# mean   250000.500000     501.400428    3225.20733
# std    144337.711634     288.641924   13098.74276
# min         1.000000       1.000000       0.00000
# 25%    125000.750000     252.000000      64.00000
# 50%    250000.500000     502.000000     141.00000
# 75%    375000.250000     752.000000     397.00000
# max    500000.000000    1000.000000   69999.00000

# %%
df_trans_zero = df_trans[df_trans.tran_amount == 0]
df_trans_zero
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120         121      440  2023-01-01            0   Amazon      Electronics
# 141         142      839  2023-01-01            0   Amazon      Electronics
# 517         518      147  2023-01-01            0   Amazon      Electronics
# 533         534      891  2023-01-01            0   Amazon      Electronics
# 586         587      108  2023-01-01            0   Amazon      Electronics
# ...         ...      ...         ...          ...      ...              ...
# 499326   499327      695  2023-09-05            0   Amazon      Electronics
# 499494   499495      295  2023-09-05            0   Amazon      Electronics
# 499708   499709      141  2023-09-05            0   Amazon      Electronics
# 499928   499929        4  2023-09-05            0   Amazon      Electronics
# 499972   499973      224  2023-09-05            0   Amazon      Electronics
#
#        payment_type
# 120     Credit Card
# ...

# %%
df_trans_zero.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 517      518      147  2023-01-01            0   Amazon      Electronics
# 533      534      891  2023-01-01            0   Amazon      Electronics
# 586      587      108  2023-01-01            0   Amazon      Electronics
#
#     payment_type
# 120  Credit Card
# 141  Credit Card
# 517  Credit Card
# 533  Credit Card
# 586  Credit Card

# %%
df_trans_zero.platform.value_counts()
# Out:
# platform
# Amazon    4734
# Name: count, dtype: int64

# %%
df_trans_zero.product_category.value_counts()
# Out:
# product_category
# Electronics    4734
# Name: count, dtype: int64

# %%
df_trans_zero[["platform","product_category","payment_type"]].value_counts()
# Out:
# platform  product_category  payment_type
# Amazon    Electronics       Credit Card     4734
# Name: count, dtype: int64

# %%
df_trans_1= df_trans[(df_trans.platform=="Amazon")&(df_trans.product_category == "Electronics")&(df_trans.payment_type=="Credit Card")]
df_trans_1.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 109      110      887  2023-01-01          635   Amazon      Electronics
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 173      174      676  2023-01-01        60439   Amazon      Electronics
# 190      191      763  2023-01-01          697   Amazon      Electronics
#
#     payment_type
# 109  Credit Card
# 120  Credit Card
# 141  Credit Card
# 173  Credit Card
# 190  Credit Card

# %%
median_to_replace = df_trans_1[df_trans_1.tran_amount>0].tran_amount.median()
median_to_replace
# Out:
# 554.0

# %%
df_trans['tran_amount'].replace(0,median_to_replace, inplace = True)

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id    tran_amount
# count  500000.000000  500000.000000  500000.000000
# mean   250000.500000     501.400428    3230.452602
# std    144337.711634     288.641924   13097.561071
# min         1.000000       1.000000       2.000000
# 25%    125000.750000     252.000000      66.000000
# 50%    250000.500000     502.000000     146.000000
# 75%    375000.250000     752.000000     413.000000
# max    500000.000000    1000.000000   69999.000000

# %%
sns.histplot(df_trans.tran_amount, bins = 30)

plt.show()

# %%
Q1,Q3 = df_trans['tran_amount'].quantile([0.25,0.75])

IQR = Q3-Q1

lower = Q1- 2* IQR
upper = Q3 + 2 * IQR

lower, upper
# Out:
# (-628.0, 1107.0)

# %%
df_trans_outlier = df_trans[df_trans.tran_amount>=upper]
df_trans_outlier.shape
# Out:
# (25000, 7)

# %%
 df_trans_normal = df_trans[df_trans.tran_amount<upper]
df_trans_normal.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
tran_mean_per_catgeory = df_trans_normal.groupby("product_category")["tran_amount"].mean()
tran_mean_per_catgeory
# Out:
# product_category
# Beauty & Personal Care     92.167205
# Books                      29.553515
# Electronics               510.172685
# Fashion & Apparel          64.553463
# Garden & Outdoor          125.630277
# Home Decor                302.487561
# Kitchen Appliances        176.773288
# Sports                    269.181631
# Toys & Games               50.333298
# Name: tran_amount, dtype: float64

# %%
df_trans_outlier.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount  platform  \
# 26        27      380  2023-01-01        61963   Shopify
# 49        50      287  2023-01-01        57869    Amazon
# 94        95      770  2023-01-01        52881      Ebay
# 104      105      549  2023-01-01        58574  Flipkart
# 113      114      790  2023-01-01        51669   Shopify
#
#            product_category payment_type
# 26   Beauty & Personal Care  Credit Card
# 49             Toys & Games         Gpay
# 94       Kitchen Appliances  Credit Card
# 104       Fashion & Apparel         Gpay
# 113      Kitchen Appliances  Credit Card

# %%
df_trans.loc[df_trans_outlier.index,"tran_amount"] = df_trans_outlier['product_category'].map(tran_mean_per_catgeory)

# %%
df_trans.loc[df_trans_outlier.index]
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 26           27      380  2023-01-01    92.167205   Shopify
# 49           50      287  2023-01-01    50.333298    Amazon
# 94           95      770  2023-01-01   176.773288      Ebay
# 104         105      549  2023-01-01    64.553463  Flipkart
# 113         114      790  2023-01-01   176.773288   Shopify
# ...         ...      ...         ...          ...       ...
# 499742   499743      868  2023-09-05    64.553463    Meesho
# 499888   499889      614  2023-09-05    64.553463    Meesho
# 499900   499901      811  2023-09-05   269.181631  Flipkart
# 499966   499967      662  2023-09-05   269.181631    Meesho
# 499996   499997      569  2023-09-05    64.553463    Meesho
#
#               product_category payment_type
# 26      Beauty & Personal Care  Credit Card
# 49                Toys & Games         Gpay
# 94          Kitchen Appliances  Credit Card
# 104          Fashion & Apparel         Gpay
# ...

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01         63.0  Flipkart        Electronics
# 1        2      385  2023-01-01         99.0   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01        471.0   Shopify             Sports
# 3        4      797  2023-01-01         33.0   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01         68.0    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
sns.histplot(df_trans.tran_amount,kde = True, bins =20)
plt.show()

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01         63.0  Flipkart        Electronics
# 1        2      385  2023-01-01         99.0   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01        471.0   Shopify             Sports
# 3        4      797  2023-01-01         33.0   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01         68.0    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
sns.countplot(x = df_trans.payment_type)
# Out:
# <Axes: xlabel='payment_type', ylabel='count'>

# %%
df_cust.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
df_merged_2 = pd.merge(df_merged, df_trans, on = "cust_id" , how = "inner")
df_merged_2.head(3)
# Out:
#    cust_id           name  gender   age location      occupation  \
# 0        1  Manya Acharya  Female  51.0     City  Business Owner
# 1        1  Manya Acharya  Female  51.0     City  Business Owner
# 2        1  Manya Acharya  Female  51.0     City  Business Owner
#
#    annual_income marital_status age_group  credit_score  ...  \
# 0       358211.0        Married     49-65           749  ...
# 1       358211.0        Married     49-65           749  ...
# 2       358211.0        Married     49-65           749  ...
#
#    credit_inquiries_last_6_months  credit_limit  credit_score_range  \
# 0                             0.0       40000.0             700-749
# 1                             0.0       40000.0             700-749
# 2                             0.0       40000.0             700-749
#
#    credit_limit_mode tran_id   tran_date  tran_amount platform  \
# 0            40000.0    1283  2023-01-01         30.0  Shopify
# ...

# %%
df_merged_2.shape
# Out:
# (499477, 22)

# %%
plt.figure(figsize = (5,4))
sns.countplot(x = 'age_group', hue = 'payment_type' , data = df_merged_2 , palette = "Set3")
plt.title('Distribution of Payment types across Age groups')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(title = 'Payment Type', loc = 'upper right')

plt.show()

# %%
fix,(ax1,ax2) = plt.subplots(1,2, figsize = (12,4))
sns.countplot(x = 'age_group', hue = 'product_category' , data = df_merged_2 , ax = ax1)
ax1.set_title("Product Category Count By Age group")
ax1.set_xlabel("Age Group")
ax1.set_ylabel("Count")
ax1.legend(title = "Product Category", loc = 'upper right')

sns.countplot(x = 'age_group', hue = 'platform' , data = df_merged_2 , ax = ax2)
ax2.set_title("Platform Count By Age group")
ax2.set_xlabel("Age Group")
ax2.set_ylabel("Count")
ax2.legend(title = "Product Category", loc = 'upper right')

plt.show()

# %%
# List of categorical columns
cat_cols = ['payment_type', 'platform', 'product_category', 'marital_status', 'age_group']

num_rows = 3
# Create subplots
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 4 * num_rows))

# Flatten the axes array to make it easier to iterate
axes = axes.flatten()

# Create subplots for each categorical column
for i, cat_col in enumerate(cat_cols):
    # Calculate the average annual income for each category
    avg_tran_amount_by_category = df_merged_2.groupby(cat_col)['tran_amount'].mean().reset_index()
    
    # Sort the data by 'annual_income' before plotting
    sorted_data = avg_tran_amount_by_category.sort_values(by='tran_amount', ascending=False)
    
    sns.barplot(x=cat_col, y='tran_amount', data=sorted_data, ci=None, ax=axes[i], palette='tab10')
    axes[i].set_title(f'Average transaction amount by {cat_col}')
    axes[i].set_xlabel(cat_col)
    axes[i].set_ylabel('Average transaction amount')

    # Rotate x-axis labels for better readability
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)

# Hide any unused subplots
for i in range(len(cat_cols), len(axes)):
    fig.delaxes(axes[i])
plt.tight_layout()
plt.show()
